# %% [markdown]
# 1.	Create a python function to scrape Yelp data for 50 restaurants close to you. Think about what data you want to scrape aside from the restaurant name and location. You must pick at least three other fields. You can use beautiful soup, selenium, scrapy, and/or splinter as possible.

# %% [markdown]
# Scraping  Restaurants data from Yelp website
# The goal of this project is to scrape Yelp website to scrape information of all restaurants listed in Missouri area. At the end of this project, we will get the following data about the restaurant:
#
# Name
#
# No. of Reviews
#
# Rating
#
# Price
#
# Cuisine

# %%
# importing packages
from bs4 import BeautifulSoup
import pandas as pd

from IPython.core.display import clear_output
from random import randint
from requests import get
from time import sleep
from time import time
start_time = time()

from warnings import warn

# %%
from bs4 import BeautifulSoup as bs
import requests

#need to look at terms and conditions to know if you can scrape the website
#most websites have a file called robots.txt that you can look at to see
#if scraping is allowed. ex: google.com/robots.txt
url = 'https://www.yelp.ca/search?cflt=restaurants&find_loc=Seattle%2C%20WA%2C%20United%20States'

# %%
response = requests.get(url)

# %%
soup= bs(response.text,'html.parser')
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
all_divs = soup.find_all("div",class_="container__09f24__sxa9- hoverable__09f24__3HkY2 margin-t3__09f24__hHZsm margin-b3__09f24__3h89A padding-t3__09f24__1VTAn padding-r3__09f24__11Xv2 padding-b3__09f24__2I83c padding-l3__09f24__1JEx9 border--top__09f24__37VAs border--right__09f24__Z9jGU border--bottom__09f24__3lElq border--left__09f24__akfOa border-color--default__09f24__3Epto")

# %%
all_divs
# Out:
# [<div class="container__09f24__sxa9- hoverable__09f24__3HkY2 margin-t3__09f24__hHZsm margin-b3__09f24__3h89A padding-t3__09f24__1VTAn padding-r3__09f24__11Xv2 padding-b3__09f24__2I83c padding-l3__09f24__1JEx9 border--top__09f24__37VAs border--right__09f24__Z9jGU border--bottom__09f24__3lElq border--left__09f24__akfOa border-color--default__09f24__3Epto"><div class="border-color--default__09f24__3Epto"><div class="arrange__09f24__1Vghi border-color--default__09f24__3Epto"><div class="arrange-unit__09f24__eFC_S border-color--default__09f24__3Epto"><div class="border-color--default__09f24__3Epto"><div aria-hidden="false" class="display--inline-block__09f24__3SvIn margin-r3__09f24__3HTZd border-color--default__09f24__3Epto"><div class="border-color--default__09f24__3Epto"><div class="container__09f24__1bcr9 dontTriggerCardClick__09f24__1UCg1 container--responsive__09f24__25Lh- container__09f24__8llqV border-color--default__09f24__3Epto" data-lcp-target-id="SCROLLABLE_PHOTO_BOX" data-slid
# ...

# %%
name=[]
for div in all_divs:
    name.append(div.find("a",class_="css-166la90").text)
print(len(name))
print(name)
# Out:
# 10
# ['The Pink Door', 'Nue', 'Biscuit Bitch', 'Elliott’s Oyster House', 'List', 'Witness', 'The Walrus and the Carpenter', '2120', 'Six Seven Restaurant', 'Pike Place Chowder']

# %%
for div in all_divs:
    try:
        rest_name = div.find("a",class_="css-166la90").text
        print("Rest_Name:" + rest_name)
    except:
        print(None)
    try:
        ratings = div.find("span",{"class":"display--inline__09f24__nqZ_W border-color--default__09f24__3Epto"}).div.get('aria-label')
        print("Rest_Ratings:" + ratings)
    except:
        print(None)
    try:
        review_count = div.find("span", {"class": "reviewCount__09f24__3GsGY css-e81eai"}).text
        print("Rest_review:" + review_count)
    except:
        print(None)     
    try:
        price = div.find("span", {"class": "priceRange__09f24__2GspP css-xtpg8e"}).text
        print("Rest_Price:" + price)
    except:
        print(None) 
    try:
        rest_type = div.find("p", {"class": "text__09f24__2NHRu css-1hx6l2b"}).text
        print("Rest_type:" + rest_type)
    except:
        print(None)  
    try:
        rest_comment = div.find("p", {"class": "css-e81eai"}).text
        print("Rest_review_comment:" + rest_comment)
    except:
        print(None)
# Out:
# Rest_Name:The Pink Door
# Rest_Ratings:4.5 star rating
# Rest_review:5407
# Rest_Price:$$
# None
# Rest_review_comment:“It's a little bit on the expensive side. They don't have much vegetarian options but the food is amazing. Perfect place for a date night as the ambience is…” more
# Rest_Name:Nue
# Rest_Ratings:4 star rating
# Rest_review:1042
# Rest_Price:$$
# None
# Rest_review_comment:“Horrible management, period. We got booked for a reservation at a later time per their request. We show up and they then tell us they don't have a reservation…” more
# Rest_Name:Biscuit Bitch
# Rest_Ratings:4 star rating
# Rest_review:4023
# Rest_Price:$
# None
# Rest_review_comment:“Food was amazing!  Make sure you order online starting @ 8am to get your order quickly.  We ordered at 8am and got our order at 8:20.  By the time we were…” more
# Rest_Name:Elliott’s Oyster House
# Rest_Ratings:4 star rating
# Rest_review:3628
# Rest_Price:$$$
# None
# Rest_review_comment:“Quick Summary
# ...

# %%
def yelp_scraper(url):
    response = requests.get(url)
    soup= bs(response.text,'html.parser')
    all_divs = soup.find_all("div",class_="container__09f24__sxa9- hoverable__09f24__3HkY2 margin-t3__09f24__hHZsm margin-b3__09f24__3h89A padding-t3__09f24__1VTAn padding-r3__09f24__11Xv2 padding-b3__09f24__2I83c padding-l3__09f24__1JEx9 border--top__09f24__37VAs border--right__09f24__Z9jGU border--bottom__09f24__3lElq border--left__09f24__akfOa border-color--default__09f24__3Epto")
    return all_divs
for div in all_divs:
    try:
        rest_name = div.find("a",class_="css-166la90").text
        print("Rest_Name:" + rest_name)
    except:
        print(None)
    try:
        ratings = div.find("span",{"class":"display--inline__09f24__nqZ_W border-color--default__09f24__3Epto"}).div.get('aria-label')
        print("Rest_Ratings:" + ratings)
    except:
        print(None)
    try:
        review_count = div.find("span", {"class": "reviewCount__09f24__3GsGY css-e81eai"}).text
        print("Rest_review:" + review_count)
    except:
        print(None)     
    try:
        price = div.find("span", {"class": "priceRange__09f24__2GspP css-xtpg8e"}).text
        print("Rest_Price:" + price)
    except:
        print(None) 
    try:
        rest_type = div.find("p", {"class": "text__09f24__2NHRu css-1hx6l2b"}).text
        print("Rest_type:" + rest_type)
    except:
        print(None)  
    try:
        rest_comment = div.find("p", {"class": "css-e81eai"}).text
        print("Rest_review_comment:" + rest_comment)
    except:
        print(None)
    
    
    
#url='https://www.yelp.ca/search?cflt=restaurants&find_loc=Seattle%2C%20WA%2C%20United%20States'
#yelp_scraper(url)
# Out:
# Rest_Name:The Pink Door
# Rest_Ratings:4.5 star rating
# Rest_review:5407
# Rest_Price:$$
# None
# Rest_review_comment:“It's a little bit on the expensive side. They don't have much vegetarian options but the food is amazing. Perfect place for a date night as the ambience is…” more
# Rest_Name:Nue
# Rest_Ratings:4 star rating
# Rest_review:1042
# Rest_Price:$$
# None
# Rest_review_comment:“Horrible management, period. We got booked for a reservation at a later time per their request. We show up and they then tell us they don't have a reservation…” more
# Rest_Name:Biscuit Bitch
# Rest_Ratings:4 star rating
# Rest_review:4023
# Rest_Price:$
# None
# Rest_review_comment:“Food was amazing!  Make sure you order online starting @ 8am to get your order quickly.  We ordered at 8am and got our order at 8:20.  By the time we were…” more
# Rest_Name:Elliott’s Oyster House
# Rest_Ratings:4 star rating
# Rest_review:3628
# Rest_Price:$$$
# None
# Rest_review_comment:“Quick Summary
# ...

# %%
from bs4 import BeautifulSoup as bs
import requests

#need to look at terms and conditions to know if you can scrape the website
#most websites have a file called robots.txt that you can look at to see
#if scraping is allowed. ex: google.com/robots.txt
url = 'https://www.yelp.com/search?find_desc=Restaurants&find_loc=Maryland+Heights%2C+MO&ns=1'

# %%
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
page_soup = bs(response.text,'html.parser')
page_soup
# Out:
# <!DOCTYPE html>
# ...

# %%
mains =page_soup.find_all('div',class_="container__09f24__sxa9- hoverable__09f24__3HkY2 margin-t3__09f24__hHZsm margin-b3__09f24__3h89A padding-t3__09f24__1VTAn padding-r3__09f24__11Xv2 padding-b3__09f24__2I83c padding-l3__09f24__1JEx9 border--top__09f24__37VAs border--right__09f24__Z9jGU border--bottom__09f24__3lElq border--left__09f24__akfOa border-color--default__09f24__3Epto")
mains
# Out:
# [<div class="container__09f24__sxa9- hoverable__09f24__3HkY2 margin-t3__09f24__hHZsm margin-b3__09f24__3h89A padding-t3__09f24__1VTAn padding-r3__09f24__11Xv2 padding-b3__09f24__2I83c padding-l3__09f24__1JEx9 border--top__09f24__37VAs border--right__09f24__Z9jGU border--bottom__09f24__3lElq border--left__09f24__akfOa border-color--default__09f24__3Epto"><div class="border-color--default__09f24__3Epto"><div class="arrange__09f24__1Vghi border-color--default__09f24__3Epto"><div class="arrange-unit__09f24__eFC_S border-color--default__09f24__3Epto"><div class="border-color--default__09f24__3Epto"><div aria-hidden="false" class="display--inline-block__09f24__3SvIn margin-r3__09f24__3HTZd border-color--default__09f24__3Epto"><div class="border-color--default__09f24__3Epto"><div class="container__09f24__1bcr9 dontTriggerCardClick__09f24__1UCg1 container--responsive__09f24__25Lh- container--serpia--responsive__09f24__A6moK container__09f24__8llqV undefined border-color--default__09f24__3Ept
# ...

# %%
import pandas as pd
page_one_results = []
for main in mains:
    try:
        name = main.find("a",class_="css-166la90").text
        print("Restaurant name:",name)
        rating = main.find("span",{"class":"display--inline__09f24__nqZ_W border-color--default__09f24__3Epto"}).div.get('aria-label')
        print("Restaurant rating:",rating)
        reviewcount = main.find("span", {"class": "reviewCount__09f24__3GsGY css-e81eai"}).text
        print("Restaurant reviewcount:",reviewcount)
        
        
        comment = main.find("p", {"class": "css-e81eai"}).text
        print("Restaurant comment:",comment,'\n')
        rest_dict = {'Name':name,
                     'Rating':rating,
                     'Reviews':reviewcount,
                     'Comments':comment}
        page_one_results.append(rest_dict)
    except AttributeError as e:
        print(e)
page_one_df = pd.DataFrame(page_one_results)
page_one_df
# Out:
# Restaurant name: Loaded Elevated Nachos
# Restaurant rating: 4.5 star rating
# Restaurant reviewcount: 56
# Restaurant comment: “Walked in the door and the staff was so welcoming and nice. We ordered 2 of the shareable platters (4 types of nachos) and literally EVERYTHING was delicious.…” more
#
# Restaurant name: Salt + Smoke
# Restaurant rating: 4 star rating
# Restaurant reviewcount: 321
# Restaurant comment: “Can't speak for the food. Less than pleasurable experience with the hostess caused many to leave.” more
#
# Restaurant name: Shack Breakfast & Lunch
# Restaurant rating: 4.5 star rating
# Restaurant reviewcount: 192
# Restaurant comment: Live wait time: 0 mins
#
# Restaurant name: Chuck’s Hot Chicken
# Restaurant rating: 4.5 star rating
# Restaurant reviewcount: 44
# Restaurant comment: “I came in from out of town for meetings, so Yelped for Chicken Restaurants and found this place and we I pulled up I was a little nervous as it is very small,…” more
#
# ...

# %%
name = []
for main in mains:
    name.append(main.find("a",class_="css-166la90").text)
name
# Out:
# ['Loaded Elevated Nachos',
#  'Salt + Smoke',
#  'Shack Breakfast & Lunch',
#  'Chuck’s Hot Chicken',
#  '314 Social',
#  'Cobalt Smoke & Sea',
#  'Fire Chicken',
#  'Fratelli’s Ristorante',
#  'Firebirds Wood Fired Grill',
#  'Companion Cafe - Saint Louis']

# %%
all_restaurants = []

for i in range(0,51):
    url = f'https://www.yelp.com/search?find_desc=Restaurants&find_loc=Maryland+Heights%2C+MO&ns=1'
    response = requests.get(url)
    page_soup = bs(response.text, 'html.parser')
    mains = page_soup.find_all('div',class_='container__09f24__sxa9- hoverable__09f24__3HkY2 margin-t3__09f24__hHZsm margin-b3__09f24__3h89A padding-t3__09f24__1VTAn padding-r3__09f24__11Xv2 padding-b3__09f24__2I83c padding-l3__09f24__1JEx9 border--top__09f24__37VAs border--right__09f24__Z9jGU border--bottom__09f24__3lElq border--left__09f24__akfOa border-color--default__09f24__3Epto')
    
    for main in mains:
        try:
            name = main.find("a",class_="css-166la90").text
            rating = main.find("span",{"class":"display--inline__09f24__nqZ_W border-color--default__09f24__3Epto"}).div.get('aria-label')
            reviewcount = main.find("span", {"class": "reviewCount__09f24__3GsGY css-e81eai"}).text
            price = main.find("span", {"class": "priceRange__09f24__2GspP css-xtpg8e"}).text
            rest_type = main.find("p", {"class": "text__09f24__2NHRu css-1hx6l2b"}).text
            comment = main.find("p", {"class": "css-e81eai"}).text
            rest_dict = {'Restaurant_Name':name,
                     'Rating':rating,
                     'Number_of_reviews':reviewcount,
                     'Price':price,
                     'Cuisine':rest_type,
                     'Comments':comment}
            all_restaurants.append(rest_dict)
        except:
               print(None)
df = pd.DataFrame(all_restaurants)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

#headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.75 Safari/537.36'}
page_one_results = []

#def getrestaurants(tag, page):
for page in range(0,51):  
    #url = f'https://stackoverflow.com/questions/tagged/{tag}?tab=Active&page={page}&pagesize=50'
    #url = f'https://www.yelp.com/search?find_desc=Restaurants&find_loc=Maryland+Heights%2C+MO&ns=1'
        url = f'https://www.yelp.ca/search?cflt=restaurants&find_loc=Seattle%2C%20WA%2C%20United%20States&start='+str(page)
        r = requests.get(url)
           
      # Wait a second in loop to not over exceed rate limit of API
        time.sleep(1.01)
        
        soup = BeautifulSoup(r.text, 'html.parser')
        
        mains = soup.find_all('div', {'class':"container__09f24__sxa9- hoverable__09f24__3HkY2 margin-t3__09f24__hHZsm margin-b3__09f24__3h89A padding-t3__09f24__1VTAn padding-r3__09f24__11Xv2 padding-b3__09f24__2I83c padding-l3__09f24__1JEx9 border--top__09f24__37VAs border--right__09f24__Z9jGU border--bottom__09f24__3lElq border--left__09f24__akfOa border-color--default__09f24__3Epto"})

        for main in mains:
            name = main.find("a",class_="css-166la90").text
            print("Restaurant name:",name)
            rating = main.find("span",{"class":"display--inline__09f24__nqZ_W border-color--default__09f24__3Epto"}).div.get('aria-label')
            print("Restaurant rating:",rating)
            reviewcount = main.find("span", {"class": "reviewCount__09f24__3GsGY css-e81eai"}).text
            print("Restaurant reviewcount:",reviewcount)
            comment = main.find("p", {"class": "css-e81eai"}).text
            print("Restaurant comment:",comment,'\n')
            rest_dict = {'Name':name,
                     'Rating':rating,
                     'Reviews':reviewcount,
                     'Comments':comment}
            page_one_results.append(rest_dict)
        #return page_one_results

#for x in range(1,3):
    #getrestaurants('python', x)
    #getQuestions('flask', x)

df = pd.DataFrame(page_one_results)
#df.to_excel('stackquestions.xlsx', index=False)
#getrestaurants('Seattle',1)
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []
